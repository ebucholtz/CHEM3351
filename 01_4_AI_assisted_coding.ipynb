# %% [markdown]
# # Exploring AI-Assisted and “Vibe” Coding in Python
#
# Large language models (LLMs) are trained using massive datasets pulling information from books, websites, and other forms of written communication to learn patterns in language. They essentially are designed to predict the next word in a sentence based on words that come before it. The preditive training that it goes through becomes a method to learn grammar, style, factual information, and some would argue reasoning patterns. One particularly interesting use case is training models on computer code. Code is a computer language with rules (syntax) that must be followed. LLMs can recognize code and common programing structures in the same way they learn to recognize other human languages. The result is they are able to suggest code completion, generate functional code, and potentially explain programming logic. As such, they become powerful tools for individuals learning to code or experienced programmers to general cheminformatics workflows.
#
# <div class="alert alert-block alert-info">
# <h2>Objectives</h2>
#
# * Explore AI assisted and "vibe" coding.
# * Use autocomplete and Copilot to generate and complete Python code.
# * Explore different models available with your student Copilot Pro account.
# * Create simple matplotlib visualizations and modify them through exploration.
# * Apply “vibe coding” to creatively explore data or graphical representations without rigid instructions.
# * Reflect on how AI assistance helps or hinders your learning.
#
# <h2>External Resources</h2>
#
# * [What is vibe coding?](https://www.ibm.com/think/topics/vibe-coding)
# * [Not all AI-assisted programming is vibe coding (but vibe coding rocks)](https://simonwillison.net/2025/Mar/19/vibe-coding/)
# * [Natural Language Generation and Understanding of Big Code for AI-Assisted Programming: A Review](https://www.mdpi.com/1099-4300/25/6/888)
# * [Chat modes in VS Code](https://code.visualstudio.com/docs/copilot/chat/chat-modes)
#
# </div>

# %% [markdown]
# ## Writing Code without Assistance
#
# Theoretically you have installed VS Code and have not linked it to your GitHub CoPilot account. If you have, click on the disable AI agent image in the bottom right corner of the coding window:
#
# ![inactivate agent](inactivate_agent.jpg)
#
# You also should turn off any autocompletion in Visual Studio Code.
#
# Open Settings:
#
# Press Ctrl + , (comma) or navigate to File > Preferences > Settings
#
# Find Editor:Quick Suggestions and set to off for other, comments and strings:
#
#
# ![turn off quick suggestions](quick_suggestions.jpg)
# In this first cell, take what you have learned to create code that that calculates the number of moles of acetylsalicylic acid (ASA) in an aspirin tablet that has 325 mg of ASA. The molecualar weight of ASA is 180.16 g/mol. Store your value for molecular weight as `mw` and your calulated moles as `mols`.

# %%
# write your code here

# key
mw = 180.16
grams = 0.325
mols = grams/mw
mols
# Out:
# 0.0018039520426287746

# %% [markdown]
# Go back and turn on the quick suggestions again.
#
# ![quick suggestion on](quick_suggest_on.jpg)
#
# In the next code cell, this time print out the following line "The molecular weight of ASA is" and have it use the value stored in your molecular weight variable.
#
# The code you will write is: `print("The molecular weight of ASA is",)
#
# Start by typing `pri` observe the screen and hit tab.
#
# Add the first parenthesis `(` and observe what happens.
#
# Type the first quote `"` and observe what happens.
#
# Type the statement, and after the second quote type `,` and observe what happens.
#
# Finally type `m` after the comma and observe the possible autocomplete items. Select your variable name.
#
# Run the cell.

# %%
# write your code here

# %% [markdown]
# In the following code cell try typing `import ma` and hit Tab. Choose the python library for math.

# %%
# Write your code here

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <strong>Check your understanding</strong>
#
# How does having quick suggestions enabled benefit you in programming? What do you find confusing or surprising?

# %% [markdown]
# ## Getting started with AI-assisted coding
#
# Reopen your settings. We have Quick Suggestions enabled.
#
# We are going to disable all of them. Make sure all are set to "off."
#
# ![quick suggestions off](quick_suggestions-1.jpg)
#
# Install GitHub Copilot extension
# Go to Extensions (Ctrl+Shift+X) and make sure GitHub Copilot is installed and enabled.
#
# You should also be signed in to GitHub with an active Copilot subscription (including student Copilot Pro access).

# %% [markdown]
# Let's try to start a print statment and use autocomplete.
# ![prompt](prompt.jpg)

# %%
# Start typing the above code here

# %% [markdown]
# In the next code cell try typing `import ma` and hit Tab. What completions do you see? Try completing matplotlib.pyplot as plt.

# %%
# write your code here

# %% [markdown]
# ## Coding with Vibes
#
# Let's let Copilot take the lead to generate some code.
#
# Toggle the chat opening the View tab at the top of the screen and selecting Chat.
#
# Normally you are able to click on a new code cell or markup cell. With copilot added, you now have a new generate option. Hover over the bottom of this code cell and click generate.
#
# In the 01_2_python_basics notebook, you created code that calculated the pH of a solution that has an [H<sub>3</sub>O<sup>+</sup>] of 1.0 x 10<sup>-5</sup> M.
#
# Tell the agent to calculate the pH of a solution that has an [H<sub>3</sub>O<sup>+</sup>] of 1.0 x 10<sup>-5</sup> M.
#
# Run this code cell.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <strong>Check your understanding</strong>
#
# Explain each line of code that was generated in the above code cell.

# %% [markdown]
# The pH of a buffer solution can be calculated with the Henderson Hasselbach equation.
#
# pH = pK<sub>a</sub> - log (HA/A-)
#
# Add a generate code cell that determines the pH of a solution that is 0.1 M acetate and 0.1 M acetic acid.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <strong>Check your understanding</strong>
#
# Explain each line of code that was generated in the above code cell.

# %% [markdown]
# ## Graphing with Copilot
#
# We haven't learned how to create graphs yet, but the syntax is straight forward.
#
# The following code cell obtains data from the periodic table available at PubChem. Run the code cell.

# %%
import requests 
import pandas as pd 
url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/periodictable/CSV"
df = pd.read_csv(url)
df.head(5)
# Out:
#    AtomicNumber Symbol       Name  AtomicMass CPKHexColor  \
# 0             1      H   Hydrogen    1.008000      FFFFFF
# 1             2     He     Helium    4.002600      D9FFFF
# 2             3     Li    Lithium    7.000000      CC80FF
# 3             4     Be  Beryllium    9.012183      C2FF00
# 4             5      B      Boron   10.810000      FFB5B5
#
#   ElectronConfiguration  Electronegativity  AtomicRadius  IonizationEnergy  \
# 0                   1s1               2.20         120.0            13.598
# 1                   1s2                NaN         140.0            24.587
# 2               [He]2s1               0.98         182.0             5.392
# 3               [He]2s2               1.57         153.0             9.323
# 4           [He]2s2 2p1               2.04         192.0             8.298
#
#    ElectronAffinity OxidationStates StandardState  MeltingPoint  BoilingPoint  \
# 0             0.754          +1, -1           Gas         13.81         20.28
# ...

# %% [markdown]
# Open the AI chat with `ctrl` + `alt` + `I`.
#
# Copy the code and paste it into the chat window. Ask the AI to explain the code.

# %% [markdown]
# Add a generate code cell below. In the code cell ask the AI to generate a bar graph of ionization energy vs atomic symbol from data in the df table.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,6))
plt.bar(df['Symbol'], df['IonizationEnergy'])
plt.xlabel('Atomic Symbol')
plt.ylabel('Ionization Energy (eV)')
plt.title('Ionization Energy vs Atomic Symbol')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Ask it to redraw the plot again but color the bars by period.

# %%
import matplotlib.pyplot as plt

# Get unique periods and assign a color to each
periods = df['ElectronConfiguration'].str.extract(r'\[(\w+)\]')[0].fillna('1')
unique_periods = periods.unique()
colors = plt.cm.tab20.colors
period_color_map = {period: colors[i % len(colors)] for i, period in enumerate(unique_periods)}

# Assign colors to each element based on its period
bar_colors = periods.map(period_color_map)

plt.figure(figsize=(16,6))
plt.bar(df['Symbol'], df['IonizationEnergy'], color=bar_colors)
plt.xlabel('Atomic Symbol')
plt.ylabel('Ionization Energy (eV)')
plt.title('Ionization Energy vs Atomic Symbol (Colored by Period)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
#  <div class="alert alert-block alert-info">
#       <H1><center>Homework</center></H1>In this notebook, you had a crash course AI assisted programming.</div>

# %% [markdown]
# ## Problem 1
#
# Using the dataframe data above, create a new graph that explores periodic trends.

# %% [markdown]
# ## Problem 2
#
# Ask Copilot to create a list of all noble gases.

# %% [markdown]
# ## Personal Exploration
#
# * What surprised you about using Copilot or autocomplete?
#
# * Did you find AI suggestions useful for learning or distracting? Explain.
#
# * Would you feel confident exploring a new Python library with this approach?
#
# * What potential issues may arise by "vibe" coding?
